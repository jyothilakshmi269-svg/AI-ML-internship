# %%
import pandas as pd

# %%
df=pd.read_csv('/content/preprocessing_practice_dataset.csv')

# %%
df
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition
# 0          52350.0                   5     Calicut        No
# ...

# %%
df.head()
# Out:
#    Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0         1001  59.0    Male         HR    Masters                18
# 1         1002  49.0  Female  Marketing  Bachelors                16
# 2         1003  35.0  Female         HR        NaN                19
# 3         1004  28.0  Female         HR        PhD                 9
# 4         1005  41.0    Male         IT  Bachelors                 5
#
#    Monthly_Salary  Performance_Rating        City Attrition
# 0         52350.0                   5     Calicut        No
# 1        118008.0                   2     Chennai       Yes
# 2        119297.0                   1       Kochi       Yes
# 3         50351.0                   2  Trivandrum       Yes
# 4        113668.0                   3  Trivandrum       Yes

# %%
df.head(10)
# Out:
#    Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0         1001  59.0    Male         HR    Masters                18
# 1         1002  49.0  Female  Marketing  Bachelors                16
# 2         1003  35.0  Female         HR        NaN                19
# 3         1004  28.0  Female         HR        PhD                 9
# 4         1005  41.0    Male         IT  Bachelors                 5
# 5         1006  59.0    Male  Marketing  Bachelors                14
# 6         1007   NaN    Male  Marketing        PhD                10
# 7         1008  43.0    Male         IT        PhD                 4
# 8         1009  31.0    Male    Finance    Masters                 0
# 9         1010  31.0    Male         HR        PhD                 7
#
#    Monthly_Salary  Performance_Rating        City Attrition
# 0         52350.0                   5     Calicut        No
# 1        118008.0                   2     Chennai       Yes
# ...

# %%
df.tail()
# Out:
#     Employee_ID   Age  Gender Department Education  Experience_Years  \
# 95         1096  54.0  Female         HR   Masters                11
# 96         1097  53.0    Male  Marketing   Masters                13
# 97         1098  43.0    Male        NaN       PhD                 1
# 98         1099  44.0  Female  Marketing       PhD                18
# 99         1100  57.0  Female        NaN       NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition
# 95         48625.0                   5     Chennai       Yes
# 96        107873.0                   5  Trivandrum       Yes
# 97         97592.0                   3     Chennai        No
# 98        102052.0                   5     Calicut       Yes
# 99         69261.0                   2     Calicut        No

# %%
df.shape
# Out:
# (100, 10)

# %%
df.dtypes
# Out:
# Employee_ID             int64
# Age                   float64
# Gender                 object
# Department             object
# Education              object
# Experience_Years        int64
# Monthly_Salary        float64
# Performance_Rating      int64
# City                   object
# Attrition              object
# dtype: object

# %%
df.describe()
# Out:
#        Employee_ID        Age  Experience_Years  Monthly_Salary  \
# count   100.000000  90.000000        100.000000       90.000000
# mean   1050.500000  39.866667          9.360000    75111.988889
# std      29.011492  11.015005          6.210971    28068.924984
# min    1001.000000  21.000000          0.000000    25412.000000
# 25%    1025.750000  29.250000          4.000000    50536.250000
# 50%    1050.500000  41.000000         10.000000    72715.500000
# 75%    1075.250000  48.000000         15.000000    99079.000000
# max    1100.000000  59.000000         19.000000   119297.000000
#
#        Performance_Rating
# count          100.000000
# mean             3.230000
# std              1.476106
# min              1.000000
# 25%              2.000000
# 50%              4.000000
# 75%              5.000000
# max              5.000000

# %%
df['Employee_ID']
# Out:
# 0     1001
# 1     1002
# 2     1003
# 3     1004
# 4     1005
#       ...
# 95    1096
# 96    1097
# 97    1098
# 98    1099
# 99    1100
# Name: Employee_ID, Length: 100, dtype: int64

# %%
df[['Employee_ID','Age']]
# Out:
#     Employee_ID   Age
# 0          1001  59.0
# 1          1002  49.0
# 2          1003  35.0
# 3          1004  28.0
# 4          1005  41.0
# ..          ...   ...
# 95         1096  54.0
# 96         1097  53.0
# 97         1098  43.0
# 98         1099  44.0
# 99         1100  57.0
#
# [100 rows x 2 columns]

# %%
df.isnull()
# Out:
#     Employee_ID    Age  Gender  Department  Education  Experience_Years  \
# 0         False  False   False       False      False             False
# 1         False  False   False       False      False             False
# 2         False  False   False       False       True             False
# 3         False  False   False       False      False             False
# 4         False  False   False       False      False             False
# ..          ...    ...     ...         ...        ...               ...
# 95        False  False   False       False      False             False
# 96        False  False   False       False      False             False
# 97        False  False   False        True      False             False
# 98        False  False   False       False      False             False
# 99        False  False   False        True       True             False
#
#     Monthly_Salary  Performance_Rating   City  Attrition
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# Age                   10
# Gender                 0
# Department            10
# Education             10
# Experience_Years       0
# Monthly_Salary        10
# Performance_Rating     0
# City                  10
# Attrition              0
# dtype: int64

# %%
df['Age_mean_imputed']=df['Age'].fillna(df['Age'].mean())

# %%
df[['Age','Age_mean_imputed']]
# Out:
#      Age  Age_mean_imputed
# 0   59.0              59.0
# 1   49.0              49.0
# 2   35.0              35.0
# 3   28.0              28.0
# 4   41.0              41.0
# ..   ...               ...
# 95  54.0              54.0
# 96  53.0              53.0
# 97  43.0              43.0
# 98  44.0              44.0
# 99  57.0              57.0
#
# [100 rows x 2 columns]

# %%
df['Department_mode_imputed']=df['Department'].fillna(df['Department'].mode())

# %%
df[['Department','Department_mode_imputed']]
# Out:
#    Department Department_mode_imputed
# 0          HR                      HR
# 1   Marketing               Marketing
# 2          HR                      HR
# 3          HR                      HR
# 4          IT                      IT
# ..        ...                     ...
# 95         HR                      HR
# 96  Marketing               Marketing
# 97        NaN                     NaN
# 98  Marketing               Marketing
# 99        NaN                     NaN
#
# [100 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# Out:
# /tmp/ipykernel_3003/2607796535.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# <Axes: xlabel='Department', ylabel='Experience_Years'>

# %%
plt.title('Boxplot of Department by Experience_Years',fontsize=16)
plt.xlabel('Experience_Years',fontsize=12)
plt.ylabel('Department',fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# Out:
# /tmp/ipykernel_3003/3272043615.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# <Axes: xlabel='Department', ylabel='Experience_Years'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# Out:
# /tmp/ipykernel_3003/2531361222.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# <Axes: xlabel='Department', ylabel='Experience_Years'>

# %%
plt.figure(figsize=(10,6))
sns.pointplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# Out:
# /tmp/ipykernel_3003/4058893068.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.pointplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# <Axes: xlabel='Department', ylabel='Experience_Years'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# Out:
# /tmp/ipykernel_3003/3403112984.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df,x='Department',y='Experience_Years',palette='pastel')
# <Axes: xlabel='Department', ylabel='Experience_Years'>

# %%
from sklearn.preprocessing import LabelEncoder
encoded_data=df.copy()

# %%
label_encoder=LabelEncoder()
encoded_data['Gender_Label']=label_encoder.fit_transform(encoded_data['Gender'])

# %%
one_hot_encoded=pd.get_dummies(encoded_data['Department'],prefix='Department')
encoded_data=pd.concat([encoded_data,one_hot_encoded],axis=1)
attrition_mapping={"Yes":'First',"No":'Second'}

# %%
encoded_data['Attrition_Category'] = encoded_data['Attrition'].map(attrition_mapping)
print(encoded_data[['Gender', 'Gender_Label', 'Department','Department_HR','Department_IT','Department_Marketing','Department_Sales','Department_Finance', 'Attrition', 'Attrition_Category']].head())
# Out:
#    Gender  Gender_Label Department  Department_HR  Department_IT  \
# 0    Male             1         HR           True          False
# 1  Female             0  Marketing          False          False
# 2  Female             0         HR           True          False
# 3  Female             0         HR           True          False
# 4    Male             1         IT          False           True
#
#    Department_Marketing  Department_Sales  Department_Finance Attrition  \
# 0                 False             False               False        No
# 1                  True             False               False       Yes
# 2                 False             False               False       Yes
# 3                 False             False               False       Yes
# 4                 False             False               False       Yes
#
#   Attrition_Category
# 0             Second
# 1              First
# 2              First
# 3              First
# 4              First

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
File_path='/content/preprocessing_practice_dataset.csv'
ppt_data=pd.read_csv(File_path)
numerical_columns=['Age','Experience_Years','Performance_Rating']
ppt_data.dropna(subset=numerical_columns,inplace=True)
minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()

# %%
ppt_data['Age_MinMax']=minmax_scaler.fit_transform(ppt_data[['Age']])
ppt_data['Experience_Years_MinMax']=minmax_scaler.fit_transform(ppt_data[['Experience_Years']])
ppt_data['Age_Standard']=standard_scaler.fit_transform(ppt_data[['Age']])
ppt_data['Experience_Years_Standard']=standard_scaler.fit_transform(ppt_data[['Experience_Years']])

# %%
ppt_data[['Age','Age_MinMax','Experience_Years_MinMax','Age_Standard','Experience_Years_Standard']].head()
# Out:
#     Age  Age_MinMax  Experience_Years_MinMax  Age_Standard  \
# 0  59.0    1.000000                 0.947368      1.746756
# 1  49.0    0.736842                 0.842105      0.833817
# 2  35.0    0.368421                 1.000000     -0.444297
# 3  28.0    0.184211                 0.473684     -1.083354
# 4  41.0    0.526316                 0.263158      0.103466
#
#    Experience_Years_Standard
# 0                   1.419878
# 1                   1.097585
# 2                   1.581024
# 3                  -0.030439
# 4                  -0.675024
